# %%
import pandas as pd
import numpy as np

# %%
rawGameData = pd.read_csv("spreadspoke_scores.csv")
rawTeamData = pd.read_csv("nfl_teams.csv")

# gameData and teamData should be cleaned using Sean's procedure

# From Data88_Final_Sean_V1:
recentGameData = rawGameData.loc[rawGameData['schedule_season'] >= 2002]
gameData = recentGameData[['schedule_season', 'schedule_week', 'schedule_playoff', 'team_home', 'score_home', 'team_away', 'score_away']]
# End Sean's cleaning

# Ayush's cleaning (cleaning the teams data set):
recentTeamData = rawTeamData.dropna(subset=["team_division"])
teamData = recentTeamData[["team_name", "team_id", "team_division"]]

# Since the conference data is encapsulated in the divisional data, we can just use this function to get it.
teamData["team_conference"] = teamData["team_division"].apply(lambda x: x[:3])
## -- IMPORTANT NOTE -- ##
# There was a row in teamData where the team division did not match the team conference - the New York Jets (index 29)
#    are listed as being in the AFC East Division but the NFC conference in the original data set. I believe this is a
#    mistake, but the above line takes care of that by making the conference AFC.

# End Ayush's cleaning
# Out:
# /srv/app/venv/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
gameData
# Out:
#        schedule_season schedule_week  schedule_playoff             team_home  \
# 7872              2002             1             False       New York Giants
# 7873              2002             1             False         Buffalo Bills
# 7874              2002             1             False     Carolina Panthers
# 7875              2002             1             False         Chicago Bears
# 7876              2002             1             False    Cincinnati Bengals
# 7877              2002             1             False      Cleveland Browns
# 7878              2002             1             False        Denver Broncos
# 7879              2002             1             False     Green Bay Packers
# 7880              2002             1             False        Houston Texans
# 7881              2002             1             False  Jacksonville Jaguars
# 7882              2002             1             False        Miami Dolphins
# 7883              2002             1             False       Oakland Raiders
# 7884              2002             1             False  Tampa Bay Buccaneers
# 7885              2002             1             False      Tennessee Titans
# 7886              2002             1             False   Washington Redskins
# 7887              2002             1             False  New England Patriots
# 7888              2002             2             False       Atlanta Falcons
# 7889              2002             2             False      Baltimore Ravens
# 7890              2002             2             False     Carolina Panthers
# 7891              2002             2             False      Cleveland Browns
# 7892              2002             2             False        Dallas Cowboys
# 7893              2002             2             False    Indianapolis Colts
# 7894              2002             2             False    Kansas City Chiefs
# 7895              2002             2             False     Minnesota Vikings
# 7896              2002             2             False    New Orleans Saints
# 7897              2002             2             False         New York Jets
# 7898              2002             2             False   Pittsburgh Steelers
# 7899              2002             2             False    San Diego Chargers
# 7900              2002             2             False   San Francisco 49ers
# 7901              2002             2             False      Seattle Seahawks
# ...                ...           ...               ...                   ...
# 12648             2019            16             False      Tennessee Titans
# 12649             2019            16             False   Washington Redskins
# 12650             2019            16             False     Minnesota Vikings
# 12651             2019            17             False      Baltimore Ravens
# 12652             2019            17             False         Buffalo Bills
# 12653             2019            17             False     Carolina Panthers
# 12654             2019            17             False    Cincinnati Bengals
# 12655             2019            17             False        Dallas Cowboys
# 12656             2019            17             False        Denver Broncos
# 12657             2019            17             False         Detroit Lions
# 12658             2019            17             False        Houston Texans
# 12659             2019            17             False  Jacksonville Jaguars
# 12660             2019            17             False    Kansas City Chiefs
# 12675          35      Tennessee Titans          24
# 12676          37     Green Bay Packers          20
# 12677          31   San Francisco 49ers          20
#
# [4806 rows x 7 columns]

# %%
teamData
# Out:
#                team_name team_id team_division team_conference
# 0      Arizona Cardinals     ARI      NFC West             NFC
# 3        Atlanta Falcons     ATL     NFC South             NFC
# 4       Baltimore Ravens     BAL     AFC North             AFC
# 5          Buffalo Bills     BUF      AFC East             AFC
# 6      Carolina Panthers     CAR     NFC South             NFC
# 7          Chicago Bears     CHI     NFC North             NFC
# 8     Cincinnati Bengals     CIN     AFC North             AFC
# 9       Cleveland Browns     CLE     AFC North             AFC
# 10        Dallas Cowboys     DAL      NFC East             NFC
# 11        Denver Broncos     DEN      AFC West             AFC
# 12         Detroit Lions     DET     NFC North             NFC
# 13     Green Bay Packers      GB     NFC North             NFC
# 14        Houston Texans     HOU     AFC South             AFC
# 16    Indianapolis Colts     IND     AFC South             AFC
# 17  Jacksonville Jaguars     JAX     AFC South             AFC
# 18    Kansas City Chiefs      KC      AFC West             AFC
# 19  Los Angeles Chargers     LAC      AFC West             AFC
# 20    San Diego Chargers     LAC      AFC West             AFC
# 21      Los Angeles Rams     LAR      NFC West             NFC
# 23        Miami Dolphins     MIA      AFC East             AFC
# 24     Minnesota Vikings     MIN     NFC North             NFC
# 25  New England Patriots      NE      AFC East             AFC
# 27    New Orleans Saints      NO     NFC South             NFC
# 28       New York Giants     NYG      NFC East             NFC
# 29         New York Jets     NYJ      AFC East             AFC
# 31       Oakland Raiders     OAK      AFC West             AFC
# 32   Philadelphia Eagles     PHI      NFC East             NFC
# 33   Pittsburgh Steelers     PIT     AFC North             AFC
# 34      Seattle Seahawks     SEA      NFC West             NFC
# 35   San Francisco 49ers      SF      NFC West             NFC
# 36  Tampa Bay Buccaneers      TB     NFC South             NFC
# 39      Tennessee Titans     TEN     AFC South             AFC
# 40   Washington Redskins     WAS      NFC East             NFC

# %%
def getGameType(row):
    """
    A function to determine the type of game that was played.
    If the two teams' divisions match, the game is a divisional one.
    If not, but the two teams' conferences match, the game is a conference one.
    Otherwise, the game is an out-of-conference one.
    """
    
    homeDivision = row["team_home_division"]
    awayDivision = row["team_away_division"]
    if (homeDivision == awayDivision):
        return "Divisional"
    
    homeConference = row["team_home_conference"]
    awayConference = row["team_away_conference"]
    if (homeConference == awayConference):
        return "Conference"
    
    return "Out-of-conference"

# %%
# Make columns: "team_home_division", "team_home_conference", "team_away_division", "team_away_conference", and "gameType"
# Create copies of teamData to be used as the home team and away team's data
homeTeamData = teamData.copy(deep=True)
awayTeamData = teamData.copy(deep=True)

# Rename columns "team_home_..." and "team_away_..."
homeTeamData = homeTeamData.rename(mapper=(lambda x: x[0:5] + "home_" + x[5:]), axis="columns")
awayTeamData = awayTeamData.rename(mapper=(lambda x: x[0:5] + "away_" + x[5:]), axis="columns")

# Merge everything "team_home" and "team_name"
withHome = gameData.merge(homeTeamData, left_on="team_home", right_on="team_home_name")
fullData = withHome.merge(awayTeamData, left_on="team_away", right_on="team_away_name")

# Apply the getGameType function to each row and create the new gameType column
fullData["gameType"] = fullData.apply(lambda singleRow: getGameType(singleRow), axis=1)
fullData
# Out:
#       schedule_season schedule_week  schedule_playoff            team_home  \
# 0                2002             1             False      New York Giants
# 1                2007             7             False      New York Giants
# 2                2008             7             False      New York Giants
# 3                2014            11             False      New York Giants
# 4                2015             5             False      New York Giants
# 5                2008            13             False        Buffalo Bills
# 6                2016             6             False        Buffalo Bills
# 7                2007            13             False    Carolina Panthers
# 8                2010             7             False    Carolina Panthers
# 9                2013      Division              True    Carolina Panthers
# 10               2016             2             False    Carolina Panthers
# 11               2004             8             False        Chicago Bears
# 12               2005            10             False        Chicago Bears
# 13               2006             8             False        Chicago Bears
# 14               2015            13             False        Chicago Bears
# 15               2016            13             False        Chicago Bears
# 16               2017            13             False        Chicago Bears
# 17               2003            15             False   Cincinnati Bengals
# 18               2011             3             False   Cincinnati Bengals
# 19               2019             2             False   Cincinnati Bengals
# 20               2007            17             False     Cleveland Browns
# 21               2015            14             False     Cleveland Browns
# 22               2006            17             False       Denver Broncos
# 23               2014             7             False       Denver Broncos
# 24               2003            12             False    Green Bay Packers
# 25               2009            11             False    Green Bay Packers
# 26               2010            13             False    Green Bay Packers
# 27               2012             1             False    Green Bay Packers
# 28               2013      Wildcard              True    Green Bay Packers
# 29               2018             6             False    Green Bay Packers
# ...               ...           ...               ...                  ...
# 4549             2014            10             False     Seattle Seahawks
# 4550             2002             4             False    Arizona Cardinals
# 4551             2004            10             False    Arizona Cardinals
# 4552             2008            12             False    Arizona Cardinals
# 4553             2011             4             False    Arizona Cardinals
# 4554             2017            16             False    Arizona Cardinals
# 4555             2007            11             False        Detroit Lions
# 4556             2013            16             False        Detroit Lions
# 4557             2014             1             False        Detroit Lions
# 4558             2019             8             False        Detroit Lions
# 4559             2002             8             False  Philadelphia Eagles
# 4560             2003            11             False  Philadelphia Eagles
# 4561             2004             1             False  Philadelphia Eagles
# 4562             2005            14             False  Philadelphia Eagles
# 4563             2006             2             False  Philadelphia Eagles
# 4564             2006      Wildcard              True  Philadelphia Eagles
# 4565             2007            14             False  Philadelphia Eagles
# 4566             2008            10             False  Philadelphia Eagles
# 4567             2009             8             False  Philadelphia Eagles
# 4568             2010            11             False  Philadelphia Eagles
# 4569             2011             3             False  Philadelphia Eagles
# 4570             2012             4             False  Philadelphia Eagles
# 4571             2013             8             False  Philadelphia Eagles
# 4572             2014             6             False  Philadelphia Eagles
# 4573             2015             6             False  Philadelphia Eagles
# 4574             2016            16             False  Philadelphia Eagles
# 4575             2017             3             False  Philadelphia Eagles
# 4576             2018            12             False  Philadelphia Eagles
# 4577             2019            14             False  Philadelphia Eagles
# 4578             2016             7             False     Los Angeles Rams
#
#       score_home            team_away  score_away       team_home_name  \
# 0             13  San Francisco 49ers          16      New York Giants
# 1             33  San Francisco 49ers          15      New York Giants
# 12    San Francisco 49ers           SF           NFC West
# 13    San Francisco 49ers           SF           NFC West
# 14    San Francisco 49ers           SF           NFC West
# 15    San Francisco 49ers           SF           NFC West
# 16    San Francisco 49ers           SF           NFC West
# 17    San Francisco 49ers           SF           NFC West
# 18    San Francisco 49ers           SF           NFC West
# 19    San Francisco 49ers           SF           NFC West
# 20    San Francisco 49ers           SF           NFC West
# 21    San Francisco 49ers           SF           NFC West
# 22    San Francisco 49ers           SF           NFC West
# 23    San Francisco 49ers           SF           NFC West
# 24    San Francisco 49ers           SF           NFC West
# 25    San Francisco 49ers           SF           NFC West
# 26    San Francisco 49ers           SF           NFC West
# 27    San Francisco 49ers           SF           NFC West
# 28    San Francisco 49ers           SF           NFC West
# 29    San Francisco 49ers           SF           NFC West
# ...                   ...          ...                ...
# 4549      New York Giants          NYG           NFC East
# 4550      New York Giants          NYG           NFC East
# 4551      New York Giants          NYG           NFC East
# 4552      New York Giants          NYG           NFC East
# 4553      New York Giants          NYG           NFC East
# 4554      New York Giants          NYG           NFC East
# 4555      New York Giants          NYG           NFC East
# 4556      New York Giants          NYG           NFC East
# 4557      New York Giants          NYG           NFC East
# 4558      New York Giants          NYG           NFC East
# 4559      New York Giants          NYG           NFC East
# 4560      New York Giants          NYG           NFC East
# 4561      New York Giants          NYG           NFC East
# 4562      New York Giants          NYG           NFC East
# 4563      New York Giants          NYG           NFC East
# 4564      New York Giants          NYG           NFC East
# 4565      New York Giants          NYG           NFC East
# 4566      New York Giants          NYG           NFC East
# 4567      New York Giants          NYG           NFC East
# 4568      New York Giants          NYG           NFC East
# 4569      New York Giants          NYG           NFC East
# 4570      New York Giants          NYG           NFC East
# 4571      New York Giants          NYG           NFC East
# 4572      New York Giants          NYG           NFC East
# 4573      New York Giants          NYG           NFC East
# 4574      New York Giants          NYG           NFC East
# 4575      New York Giants          NYG           NFC East
# 4576      New York Giants          NYG           NFC East
# 4577      New York Giants          NYG           NFC East
# 4578      New York Giants          NYG           NFC East
#
#      team_away_conference           gameType
# 0                     NFC         Conference
# 1                     NFC         Conference
# 2                     NFC         Conference
# 3                     NFC         Conference
# 4                     NFC         Conference
# 5                     NFC  Out-of-conference
# 6                     NFC  Out-of-conference
# 7                     NFC         Conference
# 8                     NFC         Conference
# 9                     NFC         Conference
# 10                    NFC         Conference
# 11                    NFC         Conference
# 12                    NFC         Conference
# 13                    NFC         Conference
# 14                    NFC         Conference
# 15                    NFC         Conference
# 16                    NFC         Conference
# 17                    NFC  Out-of-conference
# 18                    NFC  Out-of-conference
# 19                    NFC  Out-of-conference
# 20                    NFC  Out-of-conference
# 21                    NFC  Out-of-conference
# 22                    NFC  Out-of-conference
# 23                    NFC  Out-of-conference
# 24                    NFC         Conference
# 25                    NFC         Conference
# 26                    NFC         Conference
# 27                    NFC         Conference
# 28                    NFC         Conference
# 29                    NFC         Conference
# ...                   ...                ...
# 4549                  NFC         Conference
# 4550                  NFC         Conference
# 4551                  NFC         Conference
# 4552                  NFC         Conference
# 4553                  NFC         Conference
# 4554                  NFC         Conference
# 4555                  NFC         Conference
# 4556                  NFC         Conference
# 4557                  NFC         Conference
# 4558                  NFC         Conference
# 4559                  NFC         Divisional
# 4560                  NFC         Divisional
# 4561                  NFC         Divisional
# 4562                  NFC         Divisional
# 4563                  NFC         Divisional
# 4564                  NFC         Divisional
# 4565                  NFC         Divisional
# 4566                  NFC         Divisional
# 4567                  NFC         Divisional
# 4568                  NFC         Divisional
# 4569                  NFC         Divisional
# 4570                  NFC         Divisional
# 4571                  NFC         Divisional
# 4572                  NFC         Divisional
# 4573                  NFC         Divisional
# 4574                  NFC         Divisional
# 4575                  NFC         Divisional
# 4576                  NFC         Divisional
# 4577                  NFC         Divisional
# 4578                  NFC         Conference
#
# [4579 rows x 16 columns]

# %% [markdown]
# # Win Percentages

# %%
# Make a table with five columns: team name, valid, schedule season, divisional win percentage
#    conference win percentage, and out-of-conference win percentage, each team having one row/year.

# Let's create a function that iterates through the entire table and increments values one by one.
# The best method may be to just double the entire table, swapping teams 1 and 2 to ensure that games aren't undercounted.

# The following doubles the table.
def renamer(toProcess, toRecognize, replaceValue):
    result = toProcess.find(toRecognize)
    if result != -1:
        return toProcess[:result] + replaceValue + toProcess[result + len(toRecognize):]
    else:
        return toProcess
    
doubled = fullData.copy()
doubled = doubled.rename(mapper=(lambda value: renamer(value, "home", "1")), axis="columns")
doubled = doubled.rename(mapper=(lambda value: renamer(value, "away", "2")), axis="columns")

doubledCopy = fullData.copy()
doubledCopy = doubledCopy.rename(mapper=(lambda value: renamer(value, "home", "2")), axis="columns")
doubledCopy = doubledCopy.rename(mapper=(lambda value: renamer(value, "away", "1")), axis="columns")

doubled = pd.concat([doubled, doubledCopy], sort=False)
# At this point, all games are double counted.
# To make grouping and later calculations easier, let's add more columns - divisionWin, divisionGame,
#   conferenceWin, conferenceGame, outOfConferenceWin, and outOfConferenceGame.

def gameCalculator(singleRow, desiredGameType):
    return (singleRow["gameType"] == desiredGameType)

def winCalculator(singleRow, desiredGameType):
    return (singleRow["gameType"] == desiredGameType) and (singleRow["score_1"] > singleRow["score_2"])

doubled["divisionWin"] = doubled.apply((lambda singleRow: winCalculator(singleRow, "Divisional")), axis=1)
doubled["divisionGame"] = doubled.apply((lambda singleRow: gameCalculator(singleRow, "Divisional")), axis=1)
doubled["conferenceWin"] = doubled.apply((lambda singleRow: winCalculator(singleRow, "Conference")), axis=1)
doubled["conferenceGame"] = doubled.apply((lambda singleRow: gameCalculator(singleRow, "Conference")), axis=1)
doubled["outOfConferenceWin"] = doubled.apply((lambda singleRow: winCalculator(singleRow, "Out-of-conference")), axis=1)
doubled["outOfConferenceGame"] = doubled.apply((lambda singleRow: gameCalculator(singleRow, "Out-of-conference")), axis=1)

doubled
# Out:
#       schedule_season schedule_week  schedule_playoff              team_1  \
# 4578       17     Los Angeles Rams       10     New York Giants       NYG
#
#      team_1_division         ...          team_2_id team_2_division  \
# 0           NFC East         ...                 SF        NFC West
# 1           NFC East         ...                 SF        NFC West
# 2           NFC East         ...                 SF        NFC West
# 3           NFC East         ...                 SF        NFC West
# 4           NFC East         ...                 SF        NFC West
# 5           AFC East         ...                 SF        NFC West
# 6           AFC East         ...                 SF        NFC West
# 7          NFC South         ...                 SF        NFC West
# 8          NFC South         ...                 SF        NFC West
# 9          NFC South         ...                 SF        NFC West
# 10         NFC South         ...                 SF        NFC West
# 11         NFC North         ...                 SF        NFC West
# 12         NFC North         ...                 SF        NFC West
# 13         NFC North         ...                 SF        NFC West
# 14         NFC North         ...                 SF        NFC West
# 15         NFC North         ...                 SF        NFC West
# 16         NFC North         ...                 SF        NFC West
# 17         AFC North         ...                 SF        NFC West
# 18         AFC North         ...                 SF        NFC West
# 19         AFC North         ...                 SF        NFC West
# 20         AFC North         ...                 SF        NFC West
# 21         AFC North         ...                 SF        NFC West
# 22          AFC West         ...                 SF        NFC West
# 23          AFC West         ...                 SF        NFC West
# 24         NFC North         ...                 SF        NFC West
# 25         NFC North         ...                 SF        NFC West
# 26         NFC North         ...                 SF        NFC West
# 27         NFC North         ...                 SF        NFC West
# 28         NFC North         ...                 SF        NFC West
# 29         NFC North         ...                 SF        NFC West
# ...              ...         ...                ...             ...
# 4549        NFC East         ...                SEA        NFC West
# 4550        NFC East         ...                ARI        NFC West
# 4551        NFC East         ...                ARI        NFC West
# 4552        NFC East         ...                ARI        NFC West
# 4553        NFC East         ...                ARI        NFC West
# 4554        NFC East         ...                ARI        NFC West
# 4555        NFC East         ...                DET       NFC North
# 4556        NFC East         ...                DET       NFC North
# 4557        NFC East         ...                DET       NFC North
# 4558        NFC East         ...                DET       NFC North
# 4559        NFC East         ...                PHI        NFC East
# 4560        NFC East         ...                PHI        NFC East
# 4561        NFC East         ...                PHI        NFC East
# 4562        NFC East         ...                PHI        NFC East
# 4563        NFC East         ...                PHI        NFC East
# 4564        NFC East         ...                PHI        NFC East
# 4565        NFC East         ...                PHI        NFC East
# 4566        NFC East         ...                PHI        NFC East
# 4567        NFC East         ...                PHI        NFC East
# 4568        NFC East         ...                PHI        NFC East
# 4569        NFC East         ...                PHI        NFC East
# 4570        NFC East         ...                PHI        NFC East
# 4571        NFC East         ...                PHI        NFC East
# 4572        NFC East         ...                PHI        NFC East
# 4573        NFC East         ...                PHI        NFC East
# 4574        NFC East         ...                PHI        NFC East
# 4575        NFC East         ...                PHI        NFC East
# 4576        NFC East         ...                PHI        NFC East
# 4577        NFC East         ...                PHI        NFC East
# 4578        NFC East         ...                LAR        NFC West
#
#      team_2_conference           gameType divisionWin divisionGame  \
# 0                  NFC         Conference       False        False
# 1                  NFC         Conference       False        False
# 2                  NFC         Conference       False        False
# 3                  NFC         Conference       False        False
# 4                  NFC         Conference       False        False
# 5                  NFC  Out-of-conference       False        False
# 6                  NFC  Out-of-conference       False        False
# 7                  NFC         Conference       False        False
# 8                  NFC         Conference       False        False
# 9                  NFC         Conference       False        False
# 10                 NFC         Conference       False        False
# 11                 NFC         Conference       False        False
# 12                 NFC         Conference       False        False
# 13                 NFC         Conference       False        False
# 14                 NFC         Conference       False        False
# 15                 NFC         Conference       False        False
# 16                 NFC         Conference       False        False
# 17                 NFC  Out-of-conference       False        False
# 18                 NFC  Out-of-conference       False        False
# 19                 NFC  Out-of-conference       False        False
# 20                 NFC  Out-of-conference       False        False
# 21                 NFC  Out-of-conference       False        False
# 22                 NFC  Out-of-conference       False        False
# 23                 NFC  Out-of-conference       False        False
# 24                 NFC         Conference       False        False
# 25                 NFC         Conference       False        False
# 26                 NFC         Conference       False        False
# 27                 NFC         Conference       False        False
# 28                 NFC         Conference       False        False
# 29                 NFC         Conference       False        False
# ...                ...                ...         ...          ...
# 4549               NFC         Conference       False        False
# 4550               NFC         Conference       False        False
# 4551               NFC         Conference       False        False
# 4552               NFC         Conference       False        False
# 4553               NFC         Conference       False        False
# 4554               NFC         Conference       False        False
# 4555               NFC         Conference       False        False
# 4556               NFC         Conference       False        False
# 4557               NFC         Conference       False        False
# 4558               NFC         Conference       False        False
# 4559               NFC         Divisional       False         True
# 4560               NFC         Divisional       False         True
# 4561               NFC         Divisional       False         True
# 4562               NFC         Divisional        True         True
# 4563               NFC         Divisional        True         True
# 4564               NFC         Divisional       False         True
# 4565               NFC         Divisional        True         True
# 4566               NFC         Divisional        True         True
# 4567               NFC         Divisional       False         True
# 4568               NFC         Divisional       False         True
# 4569               NFC         Divisional        True         True
# 4570               NFC         Divisional       False         True
# 4571               NFC         Divisional        True         True
# 4572               NFC         Divisional       False         True
# 4573               NFC         Divisional       False         True
# 4574               NFC         Divisional       False         True
# 4575               NFC         Divisional       False         True
# 4576               NFC         Divisional       False         True
# 4577               NFC         Divisional       False         True
# 4578               NFC         Conference       False        False
#
#       conferenceWin  conferenceGame  outOfConferenceWin  outOfConferenceGame
# 0             False            True               False                False
# 1              True            True               False                False
# 2              True            True               False                False
# 3             False            True               False                False
# 4              True            True               False                False
# 5             False           False               False                 True
# 6             False           False                True                 True
# 7              True            True               False                False
# 8              True            True               False                False
# 9             False            True               False                False
# 10             True            True               False                False
# 11             True            True               False                False
# 12             True            True               False                False
# 13             True            True               False                False
# 14            False            True               False                False
# 15             True            True               False                False
# 16            False            True               False                False
# 17            False           False                True                 True
# 18            False           False               False                 True
# 19            False           False               False                 True
# 20            False           False                True                 True
# 21            False           False                True                 True
# 22            False           False               False                 True
# 23            False           False                True                 True
# 24             True            True               False                False
# 25             True            True               False                False
# 26             True            True               False                False
# 27            False            True               False                False
# 28            False            True               False                False
# 29             True            True               False                False
# ...             ...             ...                 ...                  ...
# 4549          False            True               False                False
# 4550          False            True               False                False
# 4551          False            True               False                False
# 4552           True            True               False                False
# 4553           True            True               False                False
# 4554          False            True               False                False
# 4555           True            True               False                False
# 4556           True            True               False                False
# 4557          False            True               False                False
# 4558          False            True               False                False
# 4559          False           False               False                False
# 4560          False           False               False                False
# 4561          False           False               False                False
# 4562          False           False               False                False
# 4563          False           False               False                False
# 4564          False           False               False                False
# 4565          False           False               False                False
# 4566          False           False               False                False
# 4567          False           False               False                False
# 4568          False           False               False                False
# 4569          False           False               False                False
# 4570          False           False               False                False
# 4571          False           False               False                False
# 4572          False           False               False                False
# 4573          False           False               False                False
# 4574          False           False               False                False
# 4575          False           False               False                False
# 4576          False           False               False                False
# 4577          False           False               False                False
# 4578           True            True               False                False
#
# [9158 rows x 22 columns]

# %%
# Now, we can group by the year and team_1 to get stats.
doubled = doubled.rename(columns = {"team_1": "teamName", "schedule_playoff": "valid"})
doubledGrouped = doubled.groupby(["schedule_season", "teamName"], as_index=asIndex)

aggDict = {}
for testColumn in ["divisionWin", "divisionGame", "conferenceWin", "conferenceGame", "outOfConferenceWin", "outOfConferenceGame"]:
    aggDict[testColumn] = np.count_nonzero

aggDict["valid"] = lambda toCount: np.count_nonzero(toCount) >= 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-836bd467b17a> in <module>
#       1 # Now, we can group by the year and team_1 to get stats.
#       2 doubled = doubled.rename(columns = {"team_1": "teamName", "schedule_playoff": "valid"})
# ----> 3 doubledGrouped = doubled.groupby(["schedule_season", "teamName"], as_index=asIndex)
#       4
#       5 aggDict = {}
#
# NameError: name 'asIndex' is not defined

# %%
percentageTable = doubledGrouped.agg(aggDict)
percentageTable

# Finally, calculate percentages.
# Make a table with five columns: team name, valid, schedule season, divisional win percentage
#    conference win percentage, and out-of-conference win percentage, each team having one row/year.

for element in ["division", "conference", "outOfConference"]:
    percentageTable[element + "WinPercent"] = 100 * percentageTable[element + "Win"] / percentageTable[element + "Game"]
    # Uncomment this line for output without number of wins and games in each category.
    # percentageTable = percentageTable.drop(columns=[element + "Win", element + "Game"])
percentageTable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-77697c265efb> in <module>
# ----> 1 percentageTable = doubledGrouped.agg(aggDict)
#       2 percentageTable
#       3
#       4 # Finally, calculate percentages.
#       5 # Make a table with five columns: team name, valid, schedule season, divisional win percentage
#
# NameError: name 'doubledGrouped' is not defined

# %% [markdown]
# The above table has data for all teams for every year, detailing their win percentages in division, in conference, and out-of-conference. It also has a table named "valid" to specify whether or not they played any playoff games.

# %%
#Hypothesis Testing:

#Null: The plots of a team's winning percentage in division, in conference, and out of conference with that team's playoff 
#      winning percentage that season will have no difference in correlation, r, values.
#Alternative: The plots of a team's winning percentage in division, in conference, and out of conference with that team's playoff 
#             winning percentage that season will have a difference in correlation, r, values.

#Test Statistic: Correlation, r, for a team's relationship between their playoff winning percentage with their in division, in 
#                in conference, and out of conference winning percentages.

# %%
def standard_units(series): #converts a series to be in standard units so we can calculate correlation
    return (series-np.mean(series))/np.std(series)

def r_calculator(x, y): #Will be used to determine the correlation, r
    return np.mean(standard_units(x)*standard_units(y))
