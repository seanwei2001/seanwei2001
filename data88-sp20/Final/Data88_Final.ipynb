# %%
import numpy as np
import pandas as pd
import datascience as ds
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_games = pd.read_csv('spreadspoke_scores.csv')
teams = pd.read_csv('nfl_teams.csv')
recent = all_games.loc[all_games['schedule_season'] >= 2002]
recent
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 7872     09/05/2002             2002             1             False
# 7873     09/08/2002             2002             1             False
# 7874     09/08/2002             2002             1             False
# 7875     09/08/2002             2002             1             False
# 7876     09/08/2002             2002             1             False
# 7877     09/08/2002             2002             1             False
# 7878     09/08/2002             2002             1             False
# 7879     09/08/2002             2002             1             False
# 7880     09/08/2002             2002             1             False
# 7881     09/08/2002             2002             1             False
# 7882     09/08/2002             2002             1             False
# 7883     09/08/2002             2002             1             False
# 7884     09/08/2002             2002             1             False
# ...

# %%
games = recent[['schedule_season', 'schedule_week', 'schedule_playoff', 'team_home', 'score_home', 'team_away', 'score_away']]
games.head()
# Out:
#       schedule_season schedule_week  schedule_playoff           team_home  \
# 7872             2002             1             False     New York Giants
# 7873             2002             1             False       Buffalo Bills
# 7874             2002             1             False   Carolina Panthers
# 7875             2002             1             False       Chicago Bears
# 7876             2002             1             False  Cincinnati Bengals
#
#       score_home            team_away  score_away
# 7872          13  San Francisco 49ers          16
# 7873          31        New York Jets          37
# 7874          10     Baltimore Ravens           7
# 7875          27    Minnesota Vikings          23
# 7876           6   San Diego Chargers          34

# %%
# Out:
# Empty DataFrame
# Columns: [schedule_season, schedule_week, schedule_playoff, team_home, score_home, team_away, score_away]
# Index: []
